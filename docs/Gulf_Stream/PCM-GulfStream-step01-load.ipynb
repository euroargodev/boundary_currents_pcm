# %% [markdown]
# # 🐳 Develop a PCM for the Gulf Stream Extension region
#
# Notebook toward a [Profile Classification Models (PCM)](https://pyxpcm.readthedocs.io/en/latest/overview.html) for the Gulf Stream.
#
# # ✅ Step 1: assemble a training set
#
# Using [argopy](https://argopy.readthedocs.io/), we load all QC=1 T/S data from the Gulf Stream Extension region, from 2000/01/01 to 2021/12/31.
#
# Since this represents more than 39000 profiles, we run the entire pre-processing on monthly chunk of data (and saved netcdf files for each months).
#
# Then we load the monthly timeseries of final profiles and assemble a single dataset with all data in 1 file saved in ``/docs/data/Argo-GulfStreamBox-prof-sdl.nc``.
#
# ⚠  Profiles are interpolated on standard 10db pressure levels from 0 to 1500db. Hence all profiles not reaching 1500db are dropped out.
#
#
# ⚠  You should use a deepest level that will be deep enough to handle the vertical axis of the PCM in step 2. I.e. if you choose 1500db in here, you won't be able to train a PCM on a 0-2000db vertical axis. And on the other hand, if you want a 0-500db PCM, then using 1500db here will make you miss a lot of profiles ... This is a compromise between the speed of assembling a training set and trials in PCM development phase.

# %%
import sys, os
import numpy as np
import xarray as xr
xr.set_options(display_style="html", display_expand_attrs=False);
import pandas as pd

sys.path.insert(0, "/Users/gmaze/git/github/euroargodev/argopy")
import argopy
argopy.clear_cache()
argopy.status(refresh=5)
argopy.set_options(ftp='/Volumes/CORIOLIS-GDAC')  # Use to get the index and estimate to nb of profiles in the area

sys.path.insert(0, "/Users/gmaze/git/github/euroargodev/boundary_currents_pcm")
# sys.path.insert(0, os.sep.join([os.getcwd(), '..', '..']))  # From binder
from pcmbc.utilities import from_misc_pres_2_std_depth, process_list_in_parallel
from pcmbc.plot import Plotter
# Out:
# /Users/gmaze/miniconda3/envs/virtualfleet/lib/python3.8/site-packages/pyproj/__init__.py:89: UserWarning: pyproj unable to set database path.
#   _pyproj_global_context_initialize()
# HTML(value='<table><tr><td><img src="https://img.shields.io/static/v1?style=flat-square&label=src%20argovis%20…

# %% [markdown]
# # 🔹  Define where to save and name of output files

# %%
data_output_folder = 'data'  # Relative to this notebook file location
domain_nickname = 'GulfStream'  # This will be used to name all files created in this notebook

# domain_nickname = 'WestMed'  # This will be used to name all files created in this notebook

# %% [markdown]
# # 🔹  Define the domain to download data for
#
# The box here should encompasses a larger area that the core of BC current, in order to show to the classifier enough profiles with different structures.

# %%
# [lon_min, lon_max, lat_min, lat_max]

box = [-75.,-35.,35,50.]  # Gulf Stream Extension

# box = [-1., 5., 35., 42.]  # Western Mediterranean (Extended)
# box = [-0.5, 5.6, 38.8, 41.4]  # Western Mediterranean
# box = [-10., -6., 32., 38.5]  # Gulf of Cadiz (Extended)
# box = [-20., 5. ,69., 77.]  # Nordic Seas (western part)
# box = [-20., 15. , 65., 77.]  # Nordic Seas (Extended)

# %% [markdown]
# Indicate below the maximum pressure ALL profiles will be required to reach to be selected:
#
# ⚠  You should use a deepest level that will be deep enough to handle the vertical axis of the PCM in step 2. I.e. if you choose 1500db in here, you won't be able to train a PCM on a 0-2000db vertical axis. And on the other hand, if you want a 0-500db PCM, then using 1500db here will make you miss a lot of profiles ... This is a compromise between the speed of assembling a training set and trials in PCM development phase.

# %%
max_pressure = 1500

# %% [markdown]
# # 🔹 Load Argo data with argopy

# %%
# Before downloading the data, make sure it will be of reasonable size for memory !

index_box = box.copy()
index_box.append('2000-01-01')
index_box.append('2022-01-01')

index = argopy.IndexFetcher(src='gdac', cache=True).region(index_box).load()
print("%i max profiles reported for your data selection" % index.fetcher.N_FILES)
if index.fetcher.N_FILES > 5e3:
    print("""\n OH OH !\nYou have a significant amount of profiles to load, depending 
          on your data-source this may take a while or fail, or succeed ! Be warned !""")
# Out:
# 39210 max profiles reported for your data selection
#
#  OH OH !
# You have a significant amount of profiles to load, depending
#           on your data-source this may take a while or fail, or succeed ! Be warned !

# %% [markdown]
# # 🔹 Deal with a large amount of profiles
#
# ## load/process/save data for each month

# %%
if not os.path.exists(data_output_folder):
    os.mkdir(data_output_folder)
else:
    print("✅ : output folder already exists ('%s')" % data_output_folder)
    
data_output_folder_montly = os.sep.join([data_output_folder, 'monthly'])
if not os.path.exists(data_output_folder_montly):
    os.mkdir(data_output_folder_montly)
else:
    print("✅ : output folder already exists ('%s')" % data_output_folder_montly)
# Out:
# ✅ : output folder already exists ('data')
# ✅ : output folder already exists ('data/monthly')

# %%
def process_one_monthly_chunk(item=None):
    """

    Given the global variable ``box``, ``max_pressure``, ``data_output_folder``, ``domain_nickname``, 
    this function will:
    
    - load data with argopy (using src=argovis)
    - transform points to profiles
    - interp data on standard pressure levels
    
    Data are saved after each steps.
    
    Parameters
    ----------
    item: :class:`pandas:Timestamp`        
        Timestamp with the last day of the month to process. eg: 2000-01-31
        
    Returns
    -------
    The final number of profiles saved or None
    """    
    data_box = box.copy()
    data_box.append(0)   # Pres_min
    data_box.append(max_pressure)# Pres_max
    data_box.append(item.strftime('%Y-%m-01'))
    data_box.append((item + pd.Timedelta("24 hours")).strftime('%Y-%m-%d'))

    # Load points data:
    data_file = os.sep.join([data_output_folder, 'monthly', 'Argo-%s-%s.nc' % (domain_nickname, item.strftime('%Y%m'))])
    should_continue = True
    if not os.path.exists(data_file):
        # print("🔜 %s" % data_file)
        try:
            argo = argopy.DataFetcher(src='argovis', cache=True, parallel=True).region(data_box).load()
            ds = argo.data
            ds.to_netcdf(data_file)
            # print("✅ done !")
        except Exception:
            should_continue = False
            pass
    else:
        # print("👌 %s already exists" % data_file)
        ds = xr.open_dataset(data_file)
        
    # Transform points to profiles:
    data_file = os.sep.join([data_output_folder, 'monthly', 'Argo-%s-%s-prof.nc' % (domain_nickname, item.strftime('%Y%m'))])
    if not os.path.exists(data_file) and should_continue:
        # print("🔜 %s" % data_file)
        try:
            dsp = ds.argo.point2profile()
            dsp.to_netcdf(data_file)
            # print("✅ done !")
        except Exception:
            should_continue = False
            pass
    elif should_continue:
        # print("👌 %s already exists" % data_file)
        dsp = xr.open_dataset(data_file)
        
    # Interp on standard pressure levels:
    standard_pressure_levels = np.arange(0, data_box[5], 10)
    data_file = os.sep.join([data_output_folder, 'monthly', 'Argo-%s-%s-prof-sdl.nc' % (domain_nickname, item.strftime('%Y%m'))])
    if not os.path.exists(data_file) and should_continue:
        # print("🔜 %s" % data_file)
        try:
            dsi = dsp.argo.interp_std_levels(std_lev=standard_pressure_levels, axis='PRES')
            for v in dsi:
                dsi[v].attrs = dsp[v].attrs
            dsi.to_netcdf(data_file)
            # print("✅ done !")
        except Exception:
            should_continue = False
            pass
    elif should_continue:
        # print("👌 %s already exists" % data_file)
        dsi = xr.open_dataset(data_file)
        
    return len(dsi['N_PROF']) if should_continue else None

# %%
# month_list = pd.date_range(start='2000-01-01', end='2022-01-01', freq='M')
month_list = pd.date_range(start=index_box[4], end=index_box[5], freq='M')

# process_one_monthly_chunk(month_list[-1])
data, month_failed = process_list_in_parallel(process_one_monthly_chunk, month_list, errors='raise')
print("%i profiles interpolated correctly !" % np.sum(np.array([d for d in data if d])))
# Out:
#   3%|███▋                                                                                                                                         | 7/264 [00:55<10:55,  2.55s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
# /Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#   5%|██████▎                                                                                                                                     | 12/264 [01:01<08:18,  1.98s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#   9%|█████████████▎                                                                                                                              | 25/264 [01:03<02:22,  1.67it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  11%|███████████████▉                                                                                                                            | 30/264 [01:53<37:54,  9.72s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  12%|████████████████▉                                                                                                                           | 32/264 [01:54<23:12,  6.00s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
# /Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  13%|██████████████████▌                                                                                                                         | 35/264 [01:54<11:27,  3.00s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
# /Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
# /Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  14%|████████████████████▏                                                                                                                       | 38/264 [01:54<06:39,  1.77s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  15%|█████████████████████▏                                                                                                                      | 40/264 [01:54<04:50,  1.30s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  16%|██████████████████████▎                                                                                                                     | 42/264 [01:55<03:44,  1.01s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  16%|██████████████████████▊                                                                                                                     | 43/264 [01:55<03:10,  1.16it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
# /Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  18%|████████████████████████▉                                                                                                                   | 47/264 [01:56<01:38,  2.21it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  19%|███████████████████████████                                                                                                                 | 51/264 [01:57<00:56,  3.79it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  29%|████████████████████████████████████████▎                                                                                                   | 76/264 [02:15<03:05,  1.01it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  30%|█████████████████████████████████████████▎                                                                                                  | 78/264 [02:45<14:52,  4.80s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  30%|█████████████████████████████████████████▉                                                                                                  | 79/264 [02:47<12:52,  4.17s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  30%|██████████████████████████████████████████▍                                                                                                 | 80/264 [02:49<11:04,  3.61s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  31%|██████████████████████████████████████████▉                                                                                                 | 81/264 [02:50<09:03,  2.97s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  31%|███████████████████████████████████████████▍                                                                                                | 82/264 [02:52<08:24,  2.77s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  31%|████████████████████████████████████████████                                                                                                | 83/264 [02:53<06:28,  2.15s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  32%|████████████████████████████████████████████▌                                                                                               | 84/264 [02:54<05:28,  1.83s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
# /Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  33%|█████████████████████████████████████████████▌                                                                                              | 86/264 [02:55<03:54,  1.32s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
# /Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  33%|██████████████████████████████████████████████▋                                                                                             | 88/264 [02:55<02:33,  1.15it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  34%|████████████████████████████████████████████████▎                                                                                           | 91/264 [02:56<01:24,  2.04it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
# /Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  35%|█████████████████████████████████████████████████▎                                                                                          | 93/264 [02:56<01:22,  2.08it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
# /Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  36%|█████████████████████████████████████████████████▊                                                                                          | 94/264 [02:57<01:14,  2.28it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
# /Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
# /Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
# /Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
# /Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  38%|████████████████████████████████████████████████████▋                                                                                      | 100/264 [02:57<00:32,  5.09it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  39%|█████████████████████████████████████████████████████▋                                                                                     | 102/264 [02:57<00:28,  5.65it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
# /Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  39%|██████████████████████████████████████████████████████▊                                                                                    | 104/264 [02:58<00:28,  5.53it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
# /Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  40%|███████████████████████████████████████████████████████▊                                                                                   | 106/264 [02:58<00:25,  6.27it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  41%|████████████████████████████████████████████████████████▊                                                                                  | 108/264 [02:58<00:20,  7.59it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
# /Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  50%|████████████████████████████████████████████████████████████████████▉                                                                      | 131/264 [03:00<00:23,  5.68it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
# /Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  51%|███████████████████████████████████████████████████████████████████████                                                                    | 135/264 [03:25<05:30,  2.56s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  52%|███████████████████████████████████████████████████████████████████████▌                                                                   | 136/264 [03:27<05:24,  2.54s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  52%|████████████████████████████████████████████████████████████████████████▋                                                                  | 138/264 [03:29<04:29,  2.14s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  54%|███████████████████████████████████████████████████████████████████████████▎                                                               | 143/264 [03:59<12:16,  6.09s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  61%|████████████████████████████████████████████████████████████████████████████████████▏                                                      | 160/264 [04:00<01:36,  1.07it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  66%|████████████████████████████████████████████████████████████████████████████████████████████▏                                              | 175/264 [04:08<00:59,  1.50it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
# /Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
# /Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  70%|█████████████████████████████████████████████████████████████████████████████████████████████████▍                                         | 185/264 [04:16<00:50,  1.57it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  70%|█████████████████████████████████████████████████████████████████████████████████████████████████▉                                         | 186/264 [04:44<07:19,  5.63s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  72%|████████████████████████████████████████████████████████████████████████████████████████████████████▌                                      | 191/264 [05:16<07:20,  6.04s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  76%|█████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                 | 200/264 [05:20<00:53,  1.20it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  76%|█████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                 | 201/264 [05:24<01:32,  1.46s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  77%|██████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                | 202/264 [05:30<02:47,  2.71s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  77%|███████████████████████████████████████████████████████████████████████████████████████████████████████████▍                               | 204/264 [05:34<02:41,  2.70s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  78%|███████████████████████████████████████████████████████████████████████████████████████████████████████████▉                               | 205/264 [05:35<02:01,  2.05s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  78%|████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                              | 206/264 [05:48<05:00,  5.18s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  78%|████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                              | 207/264 [06:21<12:52, 13.55s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  79%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                             | 208/264 [06:23<09:31, 10.21s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  79%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████                             | 209/264 [06:27<07:30,  8.20s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  80%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                            | 210/264 [06:38<08:11,  9.11s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  80%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████                            | 211/264 [06:48<08:12,  9.29s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  81%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                          | 213/264 [06:52<04:45,  5.60s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  81%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                         | 215/264 [07:17<07:27,  9.12s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  82%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                         | 216/264 [07:18<05:25,  6.78s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  82%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                        | 217/264 [07:22<04:34,  5.83s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  83%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                       | 219/264 [07:27<03:10,  4.22s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  84%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                      | 222/264 [07:32<01:38,  2.35s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  84%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                     | 223/264 [07:33<01:12,  1.77s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  86%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                    | 226/264 [07:36<00:53,  1.40s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  86%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                   | 227/264 [07:37<00:47,  1.28s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  86%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                   | 228/264 [07:39<00:51,  1.44s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  87%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                  | 229/264 [07:39<00:38,  1.11s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  89%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏               | 234/264 [07:44<00:29,  1.03it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  90%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊              | 237/264 [07:45<00:15,  1.70it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎             | 238/264 [07:45<00:12,  2.16it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  91%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎            | 240/264 [07:47<00:14,  1.69it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  92%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉           | 243/264 [07:49<00:13,  1.52it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  93%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉          | 245/264 [07:50<00:12,  1.56it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  94%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████        | 249/264 [07:52<00:09,  1.60it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  95%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋       | 250/264 [07:53<00:09,  1.41it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  95%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏      | 251/264 [07:55<00:13,  1.05s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  95%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋      | 252/264 [07:56<00:10,  1.11it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏     | 253/264 [07:56<00:07,  1.48it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋     | 254/264 [07:56<00:05,  1.85it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  97%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎    | 255/264 [07:57<00:05,  1.73it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  97%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊    | 256/264 [07:57<00:04,  1.89it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  97%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎   | 257/264 [07:57<00:02,  2.40it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  98%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎  | 259/264 [07:58<00:01,  3.29it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  98%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉  | 260/264 [07:59<00:02,  1.80it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  99%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍ | 261/264 [08:02<00:03,  1.25s/it]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
#  99%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉ | 262/264 [08:02<00:01,  1.06it/s]/Users/gmaze/git/github/euroargodev/argopy/argopy/xarray.py:1094: UserWarning: None of the profiles can be interpolated (not reaching the requested depth range).
#   warnings.warn(
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 264/264 [08:03<00:00,  1.83s/it]
# 3066 profiles interpolated correctly !

# %% [markdown]
# ## open and concat all monthly data files into a single file

# %%
# Get the list of data files to open and concatenate:
import glob
file_list = sorted(glob.glob(os.sep.join([data_output_folder, 'monthly', 'Argo-%s-2*-prof-sdl.nc' % domain_nickname])))
print("%i files to load and merge" % len(file_list))
print("> total size on disk: %0.2f Megabytes" % (np.sum(np.array([os.path.getsize(f) for f in file_list]))*1e-6))
# Out:
# 88 files to load and merge
# > total size on disk: 13.77 Megabytes

# %%
# Load all data (monthly files)
data, failed = process_list_in_parallel(lambda item: xr.open_dataset(item), file_list, errors='raise')
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 88/88 [00:01<00:00, 46.22it/s]

# %%
# Merge them all in a single dataset:
dsi = xr.concat(data,
       dim='N_PROF',
       data_vars='minimal',
       coords='minimal',
       compat='override')
dsi = dsi.assign_coords({'N_PROF': np.arange(len(dsi['N_PROF']))})
for v in dsi:
    dsi[v].attrs = data[0][v].attrs  # Preserve attributes
dsi
# Out:
# <xarray.Dataset>
# Dimensions:            (N_PROF: 3066, PRES_INTERPOLATED: 150)
# Coordinates:
#   * N_PROF             (N_PROF) int64 0 1 2 3 4 5 ... 3061 3062 3063 3064 3065
#     TIME               (N_PROF) datetime64[ns] 2003-07-01T08:02:00 ... 2020-1...
#     LATITUDE           (N_PROF) float64 43.63 37.95 42.77 ... 37.46 48.93 35.64
#     LONGITUDE          (N_PROF) float64 -58.34 -65.79 -58.81 ... -36.1 -53.22
#   * PRES_INTERPOLATED  (PRES_INTERPOLATED) int64 0 10 20 30 ... 1470 1480 1490
# Data variables:
#     CYCLE_NUMBER       (N_PROF) int32 37 61 25 26 38 26 ... 154 114 102 12 164
#     DATA_MODE          (N_PROF) object 'D' 'D' 'D' 'D' 'D' ... 'R' 'D' 'A' 'D'
#     DIRECTION          (N_PROF) object 'A' 'A' 'A' 'A' 'A' ... 'A' 'A' 'A' 'A'
#     PLATFORM_NUMBER    (N_PROF) int32 4900136 4900133 ... 6901604 5904772
#     PRES               (N_PROF, PRES_INTERPOLATED) float64 9.0 10.0 ... 1.49e+03
#     PSAL               (N_PROF, PRES_INTERPOLATED) float64 32.08 32.06 ... 35.0
#     TEMP               (N_PROF, PRES_INTERPOLATED) float64 12.24 11.82 ... 4.714
# Attributes: (8)

# %%
# Save full dataset on file:
dsi.to_netcdf(os.sep.join([data_output_folder,'Argo-%s-prof-sdl.nc' % domain_nickname]))

# %%
dsi.to_zarr(os.sep.join([data_output_folder, 'Argo-%s-prof-sdl.zarr' % domain_nickname]))

# %% [markdown]
# ***
# This notebook has been developed within the framework of the Euro-ArgoRISE project. This project has received funding from the European Union’s Horizon 2020 research and innovation programme under grant agreement no 824131. Call INFRADEV-03-2018-2019: Individual support to ESFRI and other world-class research infrastructures.
#
# <a href="https://www.euro-argo.eu/EU-Projects/Euro-Argo-RISE-2019-2022">
# <img src="https://user-images.githubusercontent.com/59824937/146353317-56b3e70e-aed9-40e0-9212-3393d2e0ddd9.png" width="75"/>
# </a>
